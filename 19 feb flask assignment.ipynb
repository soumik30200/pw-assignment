# %% [markdown]
# ### Q1. What is Flask Framework? What are the advantages of Flask Framework?

# %% [markdown]
# ##### Flask is a web framework, it’s a Python module that lets you develop web applications easily.
#
# advantages: scalable. flexible, easy to negotiate,

# %% [markdown]
# #### Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in Jupyter Notebook.

# %%
from flask import Flask
from flask import request

app = Flask(__name__)

@app.route("/")
def hello_world():
    return "<h1>Hello, World!</h1>"

if __name__=="__main__":
    app.run(host="0.0.0.0")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from flask import Flask
#       2 from flask import request
#       4 app = Flask(__name__)
#
# ModuleNotFoundError: No module named 'flask'

# %% [markdown]
# ![image.png](attachment:cfc724ef-7580-40e7-8fad-ed479f4cc0cc.png)

# %% [markdown]
# #### Q3. What is App routing in Flask? Why do we use app routes?

# %% [markdown]
# App Routing means mapping the URLs to a specific function that will handle the logic for that URL. Modern web frameworks use more meaningful URLs to help users remember the URLs and make navigation simpler.

# %% [markdown]
# #### Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/” route to show the following details:
# ###### Company Name: ABC Corporation
# ###### Location: India
# ###### Contact Detail: 999-999-9999

# %%
from flask import Flask
app = Flask(__name__)

@app.route("/welcome")
def hello_welcome():
    return "<h1> Welcome to ABC Corporation </h1>"

@app.route("/")
def hello_welcome1():
    return "<h2> Welcome to ABC Corporation </h2></p> </h2> Location: India </h2></p> </h2> Contact Detail: 999-999-9999 </h2></p> "

if __name__=="__main__":
    app.run(host="0.0.0.0")

# %% [markdown]
# ![image.png](attachment:14f743a1-7cfd-4501-bf67-fd57e8a43540.png)

# %% [markdown]
# ![image.png](attachment:f615e329-c7cd-49c4-a78e-f8fadbf3f7df.png)

# %% [markdown]
# #### Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the url_for() function.

# %%
The url_for() function is used for flask url building
# Out:
#   Cell In[3], line 1
#     The url_for() function is used for flask url building
#         ^
# SyntaxError: invalid syntax

# %%
from flask import url_for, Flask
appFlask = Flask(__name__)
@appFlask.route('/home')
def home():
   return 'We are in Home Page!'
with appFlask.test_request_context():
    print(url_for('login'))
